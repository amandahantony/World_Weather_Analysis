# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %%
from config2 import weather_api_key

# %%
# Basic URL for openweathermap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=756f9522a4b005a9bb257a1418a87a16

# %%
# Create a set of random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
print(cities[:1])
# Out:
# ['plettenberg bay']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | plettenberg bay
# Processing Record 2 of Set 1 | porto novo
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | port lincoln
# Processing Record 5 of Set 1 | henties bay
# Processing Record 6 of Set 1 | aksarka
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | chuy
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | ulladulla
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | kirovskiy
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | san vicente
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | tapes
# Processing Record 22 of Set 1 | tashtyp
# Processing Record 23 of Set 1 | rorvik
# Processing Record 24 of Set 1 | great bend
# Processing Record 25 of Set 1 | potsdam
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | oswego
# Processing Record 28 of Set 1 | walvis bay
# Processing Record 29 of Set 1 | redmond
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | arkhara
# Processing Record 33 of Set 1 | saint anthony
# Processing Record 34 of Set 1 | fairbanks
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | west bay
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | coihaique
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | broome
# Processing Record 47 of Set 1 | severo-kurilsk
# Processing Record 48 of Set 1 | tessalit
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | mayumba
# Processing Record 2 of Set 2 | provideniya
# Processing Record 3 of Set 2 | port hedland
# Processing Record 4 of Set 2 | ailigandi
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | moron
# Processing Record 9 of Set 2 | padang
# Processing Record 10 of Set 2 | kigoma
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | necochea
# Processing Record 13 of Set 2 | burica
# City not found. Skipping...
# Processing Record 14 of Set 2 | brae
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | nome
# Processing Record 18 of Set 2 | bubaque
# Processing Record 19 of Set 2 | inhambane
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | guymon
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | namatanai
# Processing Record 27 of Set 2 | olinda
# Processing Record 28 of Set 2 | vestmannaeyjar
# Processing Record 29 of Set 2 | leh
# Processing Record 30 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | ocos
# Processing Record 33 of Set 2 | shkurinskaya
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | busselton
# Processing Record 36 of Set 2 | yumen
# Processing Record 37 of Set 2 | grindavik
# Processing Record 38 of Set 2 | tura
# Processing Record 39 of Set 2 | oum hadjer
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | kununurra
# Processing Record 42 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 2 | guider
# Processing Record 44 of Set 2 | norman wells
# Processing Record 45 of Set 2 | sobolevo
# Processing Record 46 of Set 2 | sohag
# Processing Record 47 of Set 2 | buenos aires
# Processing Record 48 of Set 2 | albany
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | yeppoon
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | muros
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | praya
# Processing Record 7 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | kirovo-chepetsk
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | mugur-aksy
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | carutapera
# Processing Record 16 of Set 3 | yantzaza
# Processing Record 17 of Set 3 | livani
# Processing Record 18 of Set 3 | havre-saint-pierre
# Processing Record 19 of Set 3 | chekhov
# Processing Record 20 of Set 3 | cayenne
# Processing Record 21 of Set 3 | bambanglipuro
# Processing Record 22 of Set 3 | melaka
# Processing Record 23 of Set 3 | gornyy
# Processing Record 24 of Set 3 | sambava
# Processing Record 25 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | lavrentiya
# Processing Record 27 of Set 3 | hambantota
# Processing Record 28 of Set 3 | rendsburg
# Processing Record 29 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 3 | el reno
# Processing Record 31 of Set 3 | bluff
# Processing Record 32 of Set 3 | iralaya
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | vetapalem
# Processing Record 36 of Set 3 | pandan
# Processing Record 37 of Set 3 | batagay-alyta
# Processing Record 38 of Set 3 | pisco
# Processing Record 39 of Set 3 | cochrane
# Processing Record 40 of Set 3 | takoradi
# Processing Record 41 of Set 3 | muisne
# Processing Record 42 of Set 3 | kilmez
# City not found. Skipping...
# Processing Record 43 of Set 3 | guarapari
# Processing Record 44 of Set 3 | matara
# Processing Record 45 of Set 3 | tarakan
# Processing Record 46 of Set 3 | husavik
# Processing Record 47 of Set 3 | naze
# Processing Record 48 of Set 3 | dalianwan
# Processing Record 49 of Set 3 | byron bay
# Processing Record 50 of Set 3 | akureyri
# Processing Record 1 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 4 | kalaleh
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | ixtapa
# Processing Record 5 of Set 4 | houma
# Processing Record 6 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 7 of Set 4 | podor
# Processing Record 8 of Set 4 | price
# Processing Record 9 of Set 4 | koutiala
# Processing Record 10 of Set 4 | kualakapuas
# Processing Record 11 of Set 4 | nautla
# Processing Record 12 of Set 4 | izumo
# Processing Record 13 of Set 4 | fauske
# Processing Record 14 of Set 4 | guanay
# Processing Record 15 of Set 4 | ancud
# Processing Record 16 of Set 4 | namibe
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | srednekolymsk
# Processing Record 19 of Set 4 | sola
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | calvinia
# Processing Record 22 of Set 4 | barrow
# Processing Record 23 of Set 4 | beringovskiy
# Processing Record 24 of Set 4 | talkha
# Processing Record 25 of Set 4 | touros
# Processing Record 26 of Set 4 | jasper
# Processing Record 27 of Set 4 | dikson
# Processing Record 28 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 4 | vaitape
# Processing Record 30 of Set 4 | kloulklubed
# Processing Record 31 of Set 4 | mogadishu
# Processing Record 32 of Set 4 | urumqi
# Processing Record 33 of Set 4 | kavaratti
# Processing Record 34 of Set 4 | bira
# Processing Record 35 of Set 4 | gizo
# Processing Record 36 of Set 4 | karera
# Processing Record 37 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 4 | saint-pierre
# Processing Record 39 of Set 4 | linjiang
# Processing Record 40 of Set 4 | gotsu
# Processing Record 41 of Set 4 | wanaka
# Processing Record 42 of Set 4 | berlevag
# Processing Record 43 of Set 4 | emba
# Processing Record 44 of Set 4 | pangnirtung
# Processing Record 45 of Set 4 | mount gambier
# Processing Record 46 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 4 | ponta do sol
# Processing Record 50 of Set 4 | avera
# Processing Record 1 of Set 5 | kibondo
# Processing Record 2 of Set 5 | union
# Processing Record 3 of Set 5 | shimoda
# Processing Record 4 of Set 5 | summerville
# Processing Record 5 of Set 5 | madison
# Processing Record 6 of Set 5 | parian dakula
# Processing Record 7 of Set 5 | ketchikan
# Processing Record 8 of Set 5 | lata
# Processing Record 9 of Set 5 | paamiut
# Processing Record 10 of Set 5 | esperance
# Processing Record 11 of Set 5 | taoudenni
# Processing Record 12 of Set 5 | leningradskiy
# Processing Record 13 of Set 5 | vagay
# Processing Record 14 of Set 5 | sokoto
# Processing Record 15 of Set 5 | vardo
# Processing Record 16 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 5 | bhuban
# Processing Record 18 of Set 5 | edd
# Processing Record 19 of Set 5 | freeport
# Processing Record 20 of Set 5 | batticaloa
# Processing Record 21 of Set 5 | phanom sarakham
# Processing Record 22 of Set 5 | kaeo
# Processing Record 23 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 24 of Set 5 | coquimbo
# Processing Record 25 of Set 5 | chitral
# Processing Record 26 of Set 5 | alice springs
# Processing Record 27 of Set 5 | sao miguel do araguaia
# Processing Record 28 of Set 5 | clyde river
# Processing Record 29 of Set 5 | bengkulu
# Processing Record 30 of Set 5 | harihar
# Processing Record 31 of Set 5 | tuatapere
# Processing Record 32 of Set 5 | san cristobal
# Processing Record 33 of Set 5 | east london
# Processing Record 34 of Set 5 | isangel
# Processing Record 35 of Set 5 | ossora
# Processing Record 36 of Set 5 | gillette
# Processing Record 37 of Set 5 | ayan
# Processing Record 38 of Set 5 | kutum
# Processing Record 39 of Set 5 | praia da vitoria
# Processing Record 40 of Set 5 | toamasina
# Processing Record 41 of Set 5 | monrovia
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | saldanha
# Processing Record 44 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 5 | camocim
# Processing Record 46 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 5 | kruisfontein
# Processing Record 48 of Set 5 | tevriz
# Processing Record 49 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 5 | antofagasta
# Processing Record 1 of Set 6 | aginskoye
# Processing Record 2 of Set 6 | galle
# Processing Record 3 of Set 6 | hamilton
# Processing Record 4 of Set 6 | ishigaki
# Processing Record 5 of Set 6 | changli
# Processing Record 6 of Set 6 | morondava
# Processing Record 7 of Set 6 | manoel urbano
# Processing Record 8 of Set 6 | dakar
# Processing Record 9 of Set 6 | auki
# Processing Record 10 of Set 6 | belmonte
# Processing Record 11 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 6 | gat
# Processing Record 13 of Set 6 | hasaki
# Processing Record 14 of Set 6 | katsuura
# Processing Record 15 of Set 6 | thompson
# Processing Record 16 of Set 6 | todos santos
# Processing Record 17 of Set 6 | talcahuano
# Processing Record 18 of Set 6 | nortelandia
# Processing Record 19 of Set 6 | marawi
# Processing Record 20 of Set 6 | fare
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | sidhi
# Processing Record 23 of Set 6 | muzquiz
# City not found. Skipping...
# Processing Record 24 of Set 6 | ilulissat
# Processing Record 25 of Set 6 | ornskoldsvik
# Processing Record 26 of Set 6 | pevek
# Processing Record 27 of Set 6 | hofn
# Processing Record 28 of Set 6 | kepanjen
# Processing Record 29 of Set 6 | lufilufi
# Processing Record 30 of Set 6 | ulundi
# Processing Record 31 of Set 6 | ayia marina
# Processing Record 32 of Set 6 | la uribe
# City not found. Skipping...
# Processing Record 33 of Set 6 | sadiqabad
# Processing Record 34 of Set 6 | jacareacanga
# Processing Record 35 of Set 6 | burnie
# Processing Record 36 of Set 6 | batemans bay
# Processing Record 37 of Set 6 | kodiak
# Processing Record 38 of Set 6 | takaka
# Processing Record 39 of Set 6 | mortka
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | stornoway
# Processing Record 42 of Set 6 | mount isa
# Processing Record 43 of Set 6 | vostok
# Processing Record 44 of Set 6 | tabuk
# Processing Record 45 of Set 6 | aksu
# Processing Record 46 of Set 6 | korla
# Processing Record 47 of Set 6 | darhan
# Processing Record 48 of Set 6 | paris
# Processing Record 49 of Set 6 | nanortalik
# Processing Record 50 of Set 6 | nueve de julio
# Processing Record 1 of Set 7 | lubango
# Processing Record 2 of Set 7 | shingu
# Processing Record 3 of Set 7 | savanur
# Processing Record 4 of Set 7 | te horo
# Processing Record 5 of Set 7 | teya
# Processing Record 6 of Set 7 | maragogi
# Processing Record 7 of Set 7 | sangar
# Processing Record 8 of Set 7 | manado
# Processing Record 9 of Set 7 | tromso
# Processing Record 10 of Set 7 | abalak
# Processing Record 11 of Set 7 | aykhal
# Processing Record 12 of Set 7 | metabetchouan
# City not found. Skipping...
# Processing Record 13 of Set 7 | half moon bay
# Processing Record 14 of Set 7 | yulara
# Processing Record 15 of Set 7 | lagoa
# Processing Record 16 of Set 7 | ojinaga
# Processing Record 17 of Set 7 | innisfail
# Processing Record 18 of Set 7 | karasjok
# Processing Record 19 of Set 7 | mascote
# Processing Record 20 of Set 7 | ballina
# Processing Record 21 of Set 7 | puerto carreno
# Processing Record 22 of Set 7 | alta floresta
# Processing Record 23 of Set 7 | sapernoye
# Processing Record 24 of Set 7 | champerico
# Processing Record 25 of Set 7 | kirkwall
# Processing Record 26 of Set 7 | guilin
# Processing Record 27 of Set 7 | mangrul pir
# Processing Record 28 of Set 7 | khartoum
# Processing Record 29 of Set 7 | saint-joseph
# Processing Record 30 of Set 7 | borogontsy
# Processing Record 31 of Set 7 | camacha
# Processing Record 32 of Set 7 | sirjan
# Processing Record 33 of Set 7 | porbandar
# Processing Record 34 of Set 7 | sassandra
# Processing Record 35 of Set 7 | camopi
# Processing Record 36 of Set 7 | udachnyy
# Processing Record 37 of Set 7 | vrangel
# Processing Record 38 of Set 7 | fairview
# Processing Record 39 of Set 7 | pec
# Processing Record 40 of Set 7 | gbarnga
# Processing Record 41 of Set 7 | kovdor
# Processing Record 42 of Set 7 | qorveh
# Processing Record 43 of Set 7 | cidreira
# Processing Record 44 of Set 7 | wanning
# Processing Record 45 of Set 7 | samarai
# Processing Record 46 of Set 7 | altay
# Processing Record 47 of Set 7 | prince rupert
# Processing Record 48 of Set 7 | kieta
# Processing Record 49 of Set 7 | nizhniy kuranakh
# Processing Record 50 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 8 | syriam
# Processing Record 2 of Set 8 | makat
# Processing Record 3 of Set 8 | joshimath
# Processing Record 4 of Set 8 | port blair
# Processing Record 5 of Set 8 | zhangye
# Processing Record 6 of Set 8 | xining
# Processing Record 7 of Set 8 | mocuba
# Processing Record 8 of Set 8 | dobeln
# Processing Record 9 of Set 8 | longyearbyen
# Processing Record 10 of Set 8 | narsaq
# Processing Record 11 of Set 8 | tambura
# Processing Record 12 of Set 8 | port elizabeth
# Processing Record 13 of Set 8 | kabinda
# Processing Record 14 of Set 8 | lompoc
# Processing Record 15 of Set 8 | broken hill
# Processing Record 16 of Set 8 | puerto suarez
# Processing Record 17 of Set 8 | deputatskiy
# Processing Record 18 of Set 8 | charlottesville
# Processing Record 19 of Set 8 | mailsi
# Processing Record 20 of Set 8 | yerbogachen
# Processing Record 21 of Set 8 | kahului
# Processing Record 22 of Set 8 | portland
# Processing Record 23 of Set 8 | yemelyanovo
# Processing Record 24 of Set 8 | quatre cocos
# Processing Record 25 of Set 8 | qui nhon
# Processing Record 26 of Set 8 | kenmare
# Processing Record 27 of Set 8 | calamar
# Processing Record 28 of Set 8 | nsanje
# Processing Record 29 of Set 8 | sao jose da coroa grande
# Processing Record 30 of Set 8 | port hardy
# Processing Record 31 of Set 8 | high level
# Processing Record 32 of Set 8 | miyako
# Processing Record 33 of Set 8 | nipawin
# Processing Record 34 of Set 8 | perth
# Processing Record 35 of Set 8 | tazmalt
# Processing Record 36 of Set 8 | sao filipe
# Processing Record 37 of Set 8 | mahibadhoo
# Processing Record 38 of Set 8 | kulunda
# Processing Record 39 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 8 | arequipa
# Processing Record 41 of Set 8 | maceio
# Processing Record 42 of Set 8 | azanka
# Processing Record 43 of Set 8 | astana
# Processing Record 44 of Set 8 | faleapuna
# City not found. Skipping...
# Processing Record 45 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 8 | okha
# Processing Record 47 of Set 8 | salalah
# Processing Record 48 of Set 8 | nyurba
# Processing Record 49 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 8 | saint-georges
# Processing Record 1 of Set 9 | predivinsk
# Processing Record 2 of Set 9 | los llanos de aridane
# Processing Record 3 of Set 9 | ulagan
# Processing Record 4 of Set 9 | nouadhibou
# Processing Record 5 of Set 9 | san carlos del zulia
# Processing Record 6 of Set 9 | baykit
# Processing Record 7 of Set 9 | san carlos de bariloche
# Processing Record 8 of Set 9 | awjilah
# Processing Record 9 of Set 9 | abu samrah
# Processing Record 10 of Set 9 | barcelona
# Processing Record 11 of Set 9 | caravelas
# Processing Record 12 of Set 9 | collie
# Processing Record 13 of Set 9 | saint-augustin
# Processing Record 14 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 9 | srikakulam
# Processing Record 16 of Set 9 | vila
# Processing Record 17 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 9 | general roca
# Processing Record 19 of Set 9 | alofi
# Processing Record 20 of Set 9 | westport
# Processing Record 21 of Set 9 | labuhan
# Processing Record 22 of Set 9 | nioro
# Processing Record 23 of Set 9 | grants
# Processing Record 24 of Set 9 | braganca paulista
# Processing Record 25 of Set 9 | gubkinskiy
# Processing Record 26 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 9 | wakkanai
# Processing Record 28 of Set 9 | altamira
# Processing Record 29 of Set 9 | asau
# Processing Record 30 of Set 9 | tual
# Processing Record 31 of Set 9 | ostrovnoy
# Processing Record 32 of Set 9 | jalu
# Processing Record 33 of Set 9 | iqaluit
# Processing Record 34 of Set 9 | qinhuangdao
# Processing Record 35 of Set 9 | daru
# Processing Record 36 of Set 9 | launceston
# Processing Record 37 of Set 9 | hovd
# Processing Record 38 of Set 9 | bay roberts
# Processing Record 39 of Set 9 | eureka
# Processing Record 40 of Set 9 | tayoltita
# Processing Record 41 of Set 9 | geraldton
# Processing Record 42 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 9 | oktyabrskiy
# Processing Record 44 of Set 9 | salinopolis
# Processing Record 45 of Set 9 | kamaishi
# Processing Record 46 of Set 9 | adrar
# Processing Record 47 of Set 9 | soyo
# Processing Record 48 of Set 9 | nuuk
# Processing Record 49 of Set 9 | helong
# Processing Record 50 of Set 9 | serenje
# Processing Record 1 of Set 10 | gold coast
# Processing Record 2 of Set 10 | sayyan
# Processing Record 3 of Set 10 | pontes e lacerda
# Processing Record 4 of Set 10 | arys
# Processing Record 5 of Set 10 | dingle
# Processing Record 6 of Set 10 | bonavista
# Processing Record 7 of Set 10 | evensk
# Processing Record 8 of Set 10 | roald
# Processing Record 9 of Set 10 | hualmay
# Processing Record 10 of Set 10 | nemuro
# Processing Record 11 of Set 10 | puerto lopez
# Processing Record 12 of Set 10 | vila franca do campo
# Processing Record 13 of Set 10 | mashhad
# Processing Record 14 of Set 10 | palm springs
# Processing Record 15 of Set 10 | khani
# Processing Record 16 of Set 10 | lerwick
# Processing Record 17 of Set 10 | mmabatho
# Processing Record 18 of Set 10 | safford
# Processing Record 19 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 20 of Set 10 | russell
# Processing Record 21 of Set 10 | pak phanang
# Processing Record 22 of Set 10 | calama
# Processing Record 23 of Set 10 | mandalgovi
# Processing Record 24 of Set 10 | gurupi
# Processing Record 25 of Set 10 | fortuna
# Processing Record 26 of Set 10 | amapa
# Processing Record 27 of Set 10 | aitape
# Processing Record 28 of Set 10 | dunedin
# Processing Record 29 of Set 10 | windhoek
# Processing Record 30 of Set 10 | golden
# Processing Record 31 of Set 10 | kailua
# Processing Record 32 of Set 10 | cockburn town
# Processing Record 33 of Set 10 | biskamzha
# Processing Record 34 of Set 10 | ntungamo
# Processing Record 35 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 36 of Set 10 | ko samui
# Processing Record 37 of Set 10 | vytegra
# Processing Record 38 of Set 10 | aklavik
# Processing Record 39 of Set 10 | marzuq
# Processing Record 40 of Set 10 | wilhelmshaven
# Processing Record 41 of Set 10 | bereda
# Processing Record 42 of Set 10 | bull savanna
# Processing Record 43 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 44 of Set 10 | banjar
# Processing Record 45 of Set 10 | kvam
# Processing Record 46 of Set 10 | bochnia
# Processing Record 47 of Set 10 | atasu
# Processing Record 48 of Set 10 | tripoli
# Processing Record 49 of Set 10 | rivera
# Processing Record 50 of Set 10 | ostersund
# Processing Record 1 of Set 11 | manutuke
# Processing Record 2 of Set 11 | givors
# Processing Record 3 of Set 11 | tazovskiy
# Processing Record 4 of Set 11 | kropotkin
# Processing Record 5 of Set 11 | ruwi
# Processing Record 6 of Set 11 | quirinopolis
# Processing Record 7 of Set 11 | manta
# Processing Record 8 of Set 11 | gigmoto
# Processing Record 9 of Set 11 | conde
# Processing Record 10 of Set 11 | maldonado
# Processing Record 11 of Set 11 | college
# Processing Record 12 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 11 | robore
# Processing Record 14 of Set 11 | ganzhou
# Processing Record 15 of Set 11 | rosa zarate
# Processing Record 16 of Set 11 | vila velha
# Processing Record 17 of Set 11 | green river
# Processing Record 18 of Set 11 | la ronge
# Processing Record 19 of Set 11 | abilene
# Processing Record 20 of Set 11 | qaqortoq
# Processing Record 21 of Set 11 | iskateley
# Processing Record 22 of Set 11 | vyshneve
# Processing Record 23 of Set 11 | sabha
# Processing Record 24 of Set 11 | ampanihy
# Processing Record 25 of Set 11 | rio grande
# Processing Record 26 of Set 11 | hauterive
# Processing Record 27 of Set 11 | neuquen
# Processing Record 28 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 29 of Set 11 | torbay
# Processing Record 30 of Set 11 | tiznit
# Processing Record 31 of Set 11 | tatawin
# Processing Record 32 of Set 11 | vila do maio
# Processing Record 33 of Set 11 | kaoma
# Processing Record 34 of Set 11 | wattegama
# Processing Record 35 of Set 11 | menongue
# Processing Record 36 of Set 11 | dolores
# Processing Record 37 of Set 11 | te anau
# Processing Record 38 of Set 11 | cooma
# Processing Record 39 of Set 11 | cam ranh
# Processing Record 40 of Set 11 | kunming
# Processing Record 41 of Set 11 | barreiras
# Processing Record 42 of Set 11 | talnakh
# Processing Record 43 of Set 11 | bardiyah
# Processing Record 44 of Set 11 | marratxi
# Processing Record 45 of Set 11 | yucca valley
# Processing Record 46 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 47 of Set 11 | banda aceh
# Processing Record 48 of Set 11 | baruun-urt
# Processing Record 49 of Set 11 | lorengau
# Processing Record 50 of Set 11 | sioux lookout
# Processing Record 1 of Set 12 | alice town
# Processing Record 2 of Set 12 | kangaatsiaq
# Processing Record 3 of Set 12 | elk city
# Processing Record 4 of Set 12 | maarianhamina
# Processing Record 5 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 12 | richards bay
# Processing Record 7 of Set 12 | novozybkov
# Processing Record 8 of Set 12 | sakakah
# Processing Record 9 of Set 12 | lebanon
# Processing Record 10 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 11 of Set 12 | marsh harbour
# Processing Record 12 of Set 12 | lephepe
# City not found. Skipping...
# Processing Record 13 of Set 12 | garowe
# Processing Record 14 of Set 12 | fuerte olimpo
# Processing Record 15 of Set 12 | farcasesti
# Processing Record 16 of Set 12 | nabire
# Processing Record 17 of Set 12 | makakilo city
# Processing Record 18 of Set 12 | brigantine
# Processing Record 19 of Set 12 | mayo
# Processing Record 20 of Set 12 | olafsvik
# Processing Record 21 of Set 12 | sadovoye
# Processing Record 22 of Set 12 | west carrollton city
# Processing Record 23 of Set 12 | luganville
# Processing Record 24 of Set 12 | hvolsvollur
# Processing Record 25 of Set 12 | tahlequah
# Processing Record 26 of Set 12 | hami
# Processing Record 27 of Set 12 | paracuru
# Processing Record 28 of Set 12 | coromoro
# Processing Record 29 of Set 12 | po
# City not found. Skipping...
# Processing Record 30 of Set 12 | hervey bay
# Processing Record 31 of Set 12 | doha
# Processing Record 32 of Set 12 | coffeyville
# Processing Record 33 of Set 12 | iwaki
# Processing Record 34 of Set 12 | kumluca
# Processing Record 35 of Set 12 | bilibino
# Processing Record 36 of Set 12 | tekeli
# Processing Record 37 of Set 12 | saurimo
# Processing Record 38 of Set 12 | buta
# Processing Record 39 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 12 | boyuibe
# Processing Record 41 of Set 12 | maria aurora
# Processing Record 42 of Set 12 | loiza
# Processing Record 43 of Set 12 | nouakchott
# Processing Record 44 of Set 12 | petropolis
# Processing Record 45 of Set 12 | luderitz
# Processing Record 46 of Set 12 | marsa matruh
# Processing Record 47 of Set 12 | vaasa
# Processing Record 48 of Set 12 | picayune
# Processing Record 49 of Set 12 | henderson
# Processing Record 50 of Set 12 | kenora
# Processing Record 1 of Set 13 | komsomolskiy
# Processing Record 2 of Set 13 | french harbor
# Processing Record 3 of Set 13 | guanica
# Processing Record 4 of Set 13 | itaituba
# Processing Record 5 of Set 13 | rudnichnyy
# Processing Record 6 of Set 13 | fukue
# Processing Record 7 of Set 13 | klaksvik
# Processing Record 8 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 9 of Set 13 | okhotsk
# Processing Record 10 of Set 13 | nara
# Processing Record 11 of Set 13 | honiara
# Processing Record 12 of Set 13 | dromolaxia
# Processing Record 13 of Set 13 | tabou
# Processing Record 14 of Set 13 | porto belo
# Processing Record 15 of Set 13 | cabo rojo
# Processing Record 16 of Set 13 | santa teresa
# Processing Record 17 of Set 13 | dauphin
# Processing Record 18 of Set 13 | esna
# Processing Record 19 of Set 13 | manokwari
# Processing Record 20 of Set 13 | pujehun
# Processing Record 21 of Set 13 | qandala
# Processing Record 22 of Set 13 | shemursha
# Processing Record 23 of Set 13 | cartagena
# Processing Record 24 of Set 13 | bombarral
# Processing Record 25 of Set 13 | haines junction
# Processing Record 26 of Set 13 | mangochi
# Processing Record 27 of Set 13 | taksimo
# Processing Record 28 of Set 13 | shangrao
# Processing Record 29 of Set 13 | castanhal
# Processing Record 30 of Set 13 | ahipara
# Processing Record 31 of Set 13 | hella
# Processing Record 32 of Set 13 | lae
# Processing Record 33 of Set 13 | lasa
# Processing Record 34 of Set 13 | itarema
# Processing Record 35 of Set 13 | shieli
# Processing Record 36 of Set 13 | muzaffargarh
# Processing Record 37 of Set 13 | kholm
# Processing Record 38 of Set 13 | chilca
# Processing Record 39 of Set 13 | anloga
# Processing Record 40 of Set 13 | aktash
# Processing Record 41 of Set 13 | makinsk
# Processing Record 42 of Set 13 | skage
# City not found. Skipping...
# Processing Record 43 of Set 13 | constitucion
# Processing Record 44 of Set 13 | amaigbo
# Processing Record 45 of Set 13 | palmer
# Processing Record 46 of Set 13 | hohhot
# Processing Record 47 of Set 13 | san quintin
# Processing Record 48 of Set 13 | amparafaravola
# Processing Record 49 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 13 | selma
# Processing Record 1 of Set 14 | tucurui
# Processing Record 2 of Set 14 | pingliang
# Processing Record 3 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 4 of Set 14 | wilmington
# Processing Record 5 of Set 14 | rio do sul
# Processing Record 6 of Set 14 | yandoon
# City not found. Skipping...
# Processing Record 7 of Set 14 | saint-denis
# Processing Record 8 of Set 14 | akyab
# Processing Record 9 of Set 14 | tilichiki
# Processing Record 10 of Set 14 | rovaniemi
# Processing Record 11 of Set 14 | karratha
# Processing Record 12 of Set 14 | zhezkazgan
# Processing Record 13 of Set 14 | ugoofaaru
# Processing Record 14 of Set 14 | nhulunbuy
# Processing Record 15 of Set 14 | dumas
# Processing Record 16 of Set 14 | atar
# Processing Record 17 of Set 14 | bom jardim
# Processing Record 18 of Set 14 | orotukan
# Processing Record 19 of Set 14 | vuktyl
# Processing Record 20 of Set 14 | sesheke
# Processing Record 21 of Set 14 | gladstone
# Processing Record 22 of Set 14 | braganca
# Processing Record 23 of Set 14 | bagdarin
# Processing Record 24 of Set 14 | lakes entrance
# Processing Record 25 of Set 14 | port moresby
# Processing Record 26 of Set 14 | guekedou
# City not found. Skipping...
# Processing Record 27 of Set 14 | verkhnevilyuysk
# Processing Record 28 of Set 14 | sarkand
# Processing Record 29 of Set 14 | marovoay
# Processing Record 30 of Set 14 | belawan
# Processing Record 31 of Set 14 | vanimo
# Processing Record 32 of Set 14 | bahar
# Processing Record 33 of Set 14 | kokkola
# Processing Record 34 of Set 14 | alugan
# Processing Record 35 of Set 14 | honningsvag
# Processing Record 36 of Set 14 | masinigudi
# Processing Record 37 of Set 14 | wagar
# Processing Record 38 of Set 14 | san jeronimo
# Processing Record 39 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 40 of Set 14 | waipawa
# Processing Record 41 of Set 14 | ilhabela
# Processing Record 42 of Set 14 | grand baie
# Processing Record 43 of Set 14 | veraval
# Processing Record 44 of Set 14 | harper
# Processing Record 45 of Set 14 | klyuchi
# Processing Record 46 of Set 14 | sao joao da barra
# Processing Record 47 of Set 14 | merritt
# Processing Record 48 of Set 14 | buala
# Processing Record 49 of Set 14 | bandar-e lengeh
# Processing Record 50 of Set 14 | meulaboh
# Processing Record 1 of Set 15 | strezhevoy
# Processing Record 2 of Set 15 | kpandu
# Processing Record 3 of Set 15 | emerald
# Processing Record 4 of Set 15 | merauke
# Processing Record 5 of Set 15 | arman
# Processing Record 6 of Set 15 | bonthe
# Processing Record 7 of Set 15 | muzhi
# Processing Record 8 of Set 15 | sao borja
# Processing Record 9 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 15 | rocha
# Processing Record 11 of Set 15 | areia branca
# Processing Record 12 of Set 15 | colon
# Processing Record 13 of Set 15 | nova olimpia
# Processing Record 14 of Set 15 | sungairaya
# Processing Record 15 of Set 15 | ambilobe
# Processing Record 16 of Set 15 | itoman
# Processing Record 17 of Set 15 | port macquarie
# Processing Record 18 of Set 15 | muroto
# Processing Record 19 of Set 15 | angoram
# Processing Record 20 of Set 15 | alihe
# Processing Record 21 of Set 15 | amara
# Processing Record 22 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 23 of Set 15 | svetlogorsk
# Processing Record 24 of Set 15 | medowie
# Processing Record 25 of Set 15 | twentynine palms
# Processing Record 26 of Set 15 | kismayo
# Processing Record 27 of Set 15 | carmaux
# Processing Record 28 of Set 15 | arroio grande
# Processing Record 29 of Set 15 | laguna
# Processing Record 30 of Set 15 | hastings
# Processing Record 31 of Set 15 | grand gaube
# Processing Record 32 of Set 15 | ponta delgada
# Processing Record 33 of Set 15 | kinsale
# Processing Record 34 of Set 15 | yako
# Processing Record 35 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 15 | tres arroyos
# Processing Record 37 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 38 of Set 15 | bud
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Plettenberg Bay -34.0527   23.3716     72.46        68           0
# 1       Porto Novo   6.4965    2.6036     80.60        94          40
# 2         Cherskiy  68.7500  161.3000     -5.03        82           0
# 3     Port Lincoln -34.7333  135.8667     65.07        65          10
# 4      Henties Bay -22.1160   14.2845     64.00        89         100
# 5          Aksarka  66.5606   67.7975    -26.39        85         100
# 6          Mataura -46.1927  168.8643     70.27        66           0
# 7             Chuy -33.6971  -53.4616     63.68        88           0
# 8   Saint-Philippe -21.3585   55.7679     87.80        62           0
# 9        Ulladulla -35.3500  150.4667     73.40        64          75
#
#    Wind Speed Country Current Description
# 0        9.04      ZA           clear sky
# 1        3.44      BJ    scattered clouds
# 2        3.56      RU           clear sky
# 3       14.23      AU           clear sky
# 4        3.00      NA     overcast clouds
# 5       25.81      RU          light snow
# 6        3.56      NZ           clear sky
# 7        5.03      UY           clear sky
# 8       10.36      RE           clear sky
# 9       12.66      AU       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Plettenberg Bay      ZA -34.0527   23.3716     72.46        68           0
# 1       Porto Novo      BJ   6.4965    2.6036     80.60        94          40
# 2         Cherskiy      RU  68.7500  161.3000     -5.03        82           0
# 3     Port Lincoln      AU -34.7333  135.8667     65.07        65          10
# 4      Henties Bay      NA -22.1160   14.2845     64.00        89         100
# 5          Aksarka      RU  66.5606   67.7975    -26.39        85         100
# 6          Mataura      NZ -46.1927  168.8643     70.27        66           0
# 7             Chuy      UY -33.6971  -53.4616     63.68        88           0
# 8   Saint-Philippe      RE -21.3585   55.7679     87.80        62           0
# 9        Ulladulla      AU -35.3500  150.4667     73.40        64          75
#
#    Wind Speed Current Description
# 0        9.04           clear sky
# 1        3.44    scattered clouds
# 2        3.56           clear sky
# 3       14.23           clear sky
# 4        3.00     overcast clouds
# 5       25.81          light snow
# 6        3.56           clear sky
# 7        5.03           clear sky
# 8       10.36           clear sky
# 9       12.66       broken clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
